# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import skimage.io

# %% [markdown]
# ## Check the image

# %%
data_folder="/Users/kanhua/Dropbox/Programming/lyft-challenge/data"

# %%
test_file=os.path.join(data_folder,"CameraRGB/258.png")
test_file_label=os.path.join(data_folder,"CameraSeg/258.png")

# %%
test_file
# Out:
# '/Users/kanhua/Dropbox/Programming/lyft-challenge/data/CameraRGB/258.png'

# %%
test_img=skimage.io.imread(test_file)

# %%
plt.imshow(test_img)

# %%
img_label=skimage.io.imread(test_file_label,format="png")
plt.imshow(img_label[:,:,0],cmap="tab10")

# %%
fig,ax=plt.subplots(1,2)
ax[0].imshow(test_img)
ax[1].imshow(img_label[:,:,0],cmap="tab10")
fig.tight_layout()
plt.savefig("./docs/example_image_pair.png",dpi=150)

# %% [markdown]
# ## Preprocess: crop the image to region of interest
# The portion of the car hood in the iamge is significant. This should be minizied during the training.

# %%
upper_cut=170
bottom_cut=520
fig,ax=plt.subplots(1,2)
ax[0].imshow(test_img[upper_cut:bottom_cut,:,:])
ax[1].imshow(img_label[upper_cut:bottom_cut,:,0],cmap="tab10")
fig.tight_layout()
plt.savefig("./docs/example_image_pair_cut.png",dpi=150)

# %% [markdown]
# ## Pixels of road

# %%
binary_label=(img_label[:,:,0]==7)
binary_label
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
plt.imshow(binary_label)

# %%
img_label.shape
# Out:
# (600, 800, 3)

# %%
one_hot_label=tf.one_hot(img_label[:,:,0],13,axis=-1,dtype=tf.int8)
one_hot_label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-51f148e976c4> in <module>()
# ----> 1 one_hot_label=tf.one_hot(img_label[:,:,0],13,axis=-1,dtype=tf.int8)
#       2 one_hot_label
#
# NameError: name 'tf' is not defined
