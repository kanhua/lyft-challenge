# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls ./data
# Out:
# Archive.zip              train_data_2.npy         train_label_baseline.npy
# CameraRGB                train_data_baseline.npy  val_data.npy
# CameraSeg                train_label.npy          val_label.npy
# train_data.npy           train_label_2.npy

# %%
label=np.load('./data/train_label_baseline.npy')

# %%
image_set=np.load('./data/train_data_baseline.npy')

# %%
image_set.shape
# Out:
# (1000, 350, 800, 3)

# %%
label.shape
# Out:
# (1000, 350, 800, 3)

# %%
plt.imshow(image_set[0])

# %%
plt.imshow(label[0,:,:,2])

# %%
veh=np.sum(label[:,:,:,2],axis=0)
