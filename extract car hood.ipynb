# %%
# %matplotlib inline
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import skimage.io

# %%
data_folder="/Users/kanhua/Dropbox/Programming/lyft-challenge/data"

# %%
test_file=os.path.join(data_folder,"CameraRGB/258.png")
test_file_label=os.path.join(data_folder,"CameraSeg/258.png")

# %%
test_file
# Out:
# '/Users/kanhua/Dropbox/Programming/lyft-challenge/data/CameraRGB/258.png'

# %%
img_label=skimage.io.imread(test_file_label,format="png")[:,:,0]
plt.imshow(img_label,cmap="tab10")

# %%
veh_label=(img_label==10)
plt.imshow(veh_label)

# %%
mask=np.zeros_like(img_label,dtype=np.bool)
mask[450:,:]=1
hood_label=np.logical_not(veh_label*mask)
plt.imshow(hood_label)

# %%
np.save("hood_mask.npy",hood_label)

# %%
loaded_mask=np.load("hood_mask.npy")
plt.imshow(loaded_mask)
